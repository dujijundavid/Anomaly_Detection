# %% [markdown]
# ## Original - Sam version
# Data:
# 1.
#
# Steps:
# 1. A randomized set of data with approximate range
# 2. dump data

# %%
import json
import sys
# generate random integer values
import random

data = {
    "BETAZRPDCOR001_1_totalAttachedUser": random.randint(1,10),
    "BETAZRPDCOR001_1_totalRejectedUser": 0,
    "BETAZRPDCOR001_1_totalBearerActiveUser": random.randint(3000,10000),
    "BETAZRPDCOR001_1_totalBearerRejectedUser": 0,
    "BETAZRPDCOR001_1_handoverFailureCount": 0,
    "BETAZRPDCOR001_1_peak_ul": random.randint(10,80),
    "BETAZRPDCOR001_1_peak_dl": random.randint(100,190),
    "BETAZRPDCOR001_1_total_dropped_packets": 0,
    "BETAZRPDCOR001_1_total_users": random.randint(1,25),
    "BETAZRPDCOR001_1_enodeb_connected_count": random.randint(1,4),
    "BETAZRPDCOR001_1_enodeb_shutdown_count": random.randint(1,4),
    "BETAZRPDCOR001_1_enodeb_connection_status": 100}


json_string = json.dumps(data)

f = open(r'gyan-report.json','w')
#sys.stdout = f
print(json_string)
#sys.stdout.close()
print("Complete")
# Out:
# {"BETAZRPDCOR001_1_totalAttachedUser": 6, "BETAZRPDCOR001_1_totalRejectedUser": 0, "BETAZRPDCOR001_1_totalBearerActiveUser": 9832, "BETAZRPDCOR001_1_totalBearerRejectedUser": 0, "BETAZRPDCOR001_1_handoverFailureCount": 0, "BETAZRPDCOR001_1_peak_ul": 69, "BETAZRPDCOR001_1_peak_dl": 187, "BETAZRPDCOR001_1_total_dropped_packets": 0, "BETAZRPDCOR001_1_total_users": 19, "BETAZRPDCOR001_1_enodeb_connected_count": 2, "BETAZRPDCOR001_1_enodeb_shutdown_count": 2, "BETAZRPDCOR001_1_enodeb_connection_status": 100}
# Complete

# %% [markdown]
# ## Data Transformer
#
# Problem with the Data
#
# - Numerical Value stored in string
# - Missing Values
#     - 54 unique column names | 224 record in total for 5 product
#
#
# **Data Exploration**
# - 6 BS_Name
# - 1 or 2 Cell Number
# - 11 BS_Name Cell Number combination

# %% [markdown]
# ## Simple Manual Generation

# %%
def random_data():
    data1 = {
        "BETBELPDENB001_1_ConnEstabFailSum": 0,
        "BETBELPDENB001_1_ConnEstabSuccSum": random.randint(10, 100),
        "BETBELPDENB001_2_ConnEstabFailSum": 0,
        "BETBELPDENB001_2_ConnEstabSuccSum": random.randint(10, 100),
        # BETBELPDENB_1 and BETBELPDENB_2
        # BETBELLBENB_
        # OnGoRadio
        # BSName_CellNUMBER pair
        # Seperate into 5 or 3
        # 3 files  dump into same json
        # 1 file or 3 files has no difference

        "BETBELPDENB001_1_TotalCellUnavailableTimeFault": 0,
        "BETBELPDENB001_1_TotalCellUnavailableTimeManualIntervention": 0,
        "BETBELPDENB001_1_TotalCellUnavailableTime": 0,
        "BETBELPDENB001_2_TotalCellUnavailableTimeFault": 0,
        "BETBELPDENB001_2_TotalCellUnavailableTimeManualIntervention": 0,
        "BETBELPDENB001_2_TotalCellUnavailableTime": 0,
        "BETBELPDENB001_1_DrbULThCapacitySum": random.randint(1000000, 10000000),
        "BETBELPDENB001_1_DrbPdcpSduAirLossRateDlSum": 0,
        "BETBELPDENB001_1_DrbMaxULThCapacity": random.randint(30000, 42000),
        "BETBELPDENB001_1_DrbPdcpSduLossRateUlSum": 0,
        "BETBELPDENB001_1_DrbDLThCapacitySum": random.randint(1000000, 10000000),
        "BETBELPDENB001_1_DrbULThCapacityAvg": random.randint(20000, 25000),
        "BETBELPDENB001_1_DrbDLThCapacityAvg": random.randint(20000, 22000),
        "BETBELPDENB001_2_DrbULThCapacitySum": random.randint(1000000, 10000000),
        "BETBELPDENB001_2_DrbPdcpSduAirLossRateDlSum": 0,
        "BETBELPDENB001_2_DrbMaxULThCapacity": random.randint(35000, 40000),
        "BETBELPDENB001_2_DrbPdcpSduLossRateUlSum": 0,
        "BETBELPDENB001_2_DrbDLThCapacitySum": random.randint(1000000, 10000000),
        "BETBELPDENB001_2_DrbULThCapacityAvg": random.randint(20000, 22000),
        "BETBELPDENB001_2_DrbDLThCapacityAvg": random.randint(20000, 22000),
        "BETBELPDENB001_1_RbDlIpLatency": 0,
        "BETBELPDENB001_1_PdcpSduAirLossDl": 0,
        "BETBELPDENB001_1_PdcpSduDropRateDl": 0,
        "BETBELPDENB001_1_PdcpTrafficUlKbps": 0,
        "BETBELPDENB001_1_IpLateSamplesDl": 0,
        "BETBELPDENB001_1_PdcpSduAirTotalDl": 0,
        "BETBELPDENB001_1_PdcpSduAirLossRateDl": 0,
        "BETBELPDENB001_1_PdcpTrafficDlKbps": 0,
        "BETBELPDENB001_2_RbDlIpLatency": 0,
        "BETBELPDENB001_2_PdcpSduAirLossDl": 0,
        "BETBELPDENB001_2_PdcpSduDropRateDl": 0,
        "BETBELPDENB001_2_PdcpTrafficUlKbps": 0,
        "BETBELPDENB001_2_IpLateSamplesDl": 0,
        "BETBELPDENB001_2_PdcpSduAirTotalDl": 0,
        "BETBELPDENB001_2_PdcpSduAirLossRateDl": 0,
        "BETBELPDENB001_2_PdcpTrafficDlKbps": 0}

    data2 = {"BETBELLBENB001_1_RbDlIpLatency": 0,
             "BETBELLBENB001_1_PdcpSduAirLossDl": 0,
             "BETBELLBENB001_1_PdcpSduDropRateDl": 0,
             "BETBELLBENB001_1_PdcpTrafficUlKbps": 0,
             "BETBELLBENB001_1_IpLateSamplesDl": 0,
             "BETBELLBENB001_1_PdcpSduAirTotalDl": 0,
             "BETBELLBENB001_1_PdcpSduAirLossRateDl": 0,
             "BETBELLBENB001_1_PdcpTrafficDlKbps": 0,
             "BETBELLBENB001_2_RbDlIpLatency": 0,
             "BETBELLBENB001_2_PdcpSduAirLossDl": 0,
             "BETBELLBENB001_2_PdcpSduDropRateDl": 0,
             "BETBELLBENB001_2_PdcpTrafficUlKbps": 0,
             "BETBELLBENB001_2_IpLateSamplesDl": 0,
             "BETBELLBENB001_2_PdcpSduAirTotalDl": 0,
             "BETBELLBENB001_2_PdcpSduAirLossRateDl": 0,
             "BETBELLBENB001_2_PdcpTrafficDlKbps": 0,
             "BETBELLBENB001_1_ConnEstabSuccSum": 0,
             "BETBELLBENB001_1_ConnEstabFailSum": 0,
             "BETBELLBENB001_2_ConnEstabSuccSum": 0,
             "BETBELLBENB001_2_ConnEstabFailSum": 0,
             "BETBELLBENB001_1_TotalCellUnavailableTime": 0,
             "BETBELLBENB001_1_TotalCellUnavailableTimeFault": 0,
             "BETBELLBENB001_1_TotalCellUnavailableTimeManualIntervention": 0,
             "BETBELLBENB001_2_TotalCellUnavailableTime": 0,
             "BETBELLBENB001_2_TotalCellUnavailableTimeFault": 0,
             "BETBELLBENB001_2_TotalCellUnavailableTimeManualIntervention": 0,
             "BETBELLBENB001_1_DrbDLThCapacityAvg": "12109.32",
             "BETBELLBENB001_1_DrbDLThCapacitySum": random.randint(100000, 1000000),
             "BETBELLBENB001_1_DrbPdcpSduLossRateUlSum": 0,
             "BETBELLBENB001_1_DrbULThCapacitySum": random.randint(100000, 1000000),
             "BETBELLBENB001_1_DrbMaxULThCapacity": random.randint(15000, 20000),
             "BETBELLBENB001_1_DrbPdcpSduAirLossRateDlSum": 0,
             "BETBELLBENB001_1_DrbULThCapacityAvg": random.randint(15000, 20000),
             "BETBELLBENB001_2_DrbDLThCapacityAvg": 0,
             "BETBELLBENB001_2_DrbDLThCapacitySum": 0,
             "BETBELLBENB001_2_DrbPdcpSduLossRateUlSum": 0,
             "BETBELLBENB001_2_DrbULThCapacitySum": 0,
             "BETBELLBENB001_2_DrbMaxULThCapacity": 0,
             "BETBELLBENB001_2_DrbPdcpSduAirLossRateDlSum": 0,
             "BETBELLBENB001_2_DrbULThCapacityAvg": 0}

    data3 = {
        "OnGoRadio001_1_ConnEstabFailSum": 0,
        "OnGoRadio001_1_ConnEstabSuccSum": 0,
        "OnGoRadio001_2_ConnEstabFailSum": 0,
        "OnGoRadio001_2_ConnEstabSuccSum": 0,
        "OnGoRadio001_1_TotalCellUnavailableTime": random.randint(200, 400),
        "OnGoRadio001_1_TotalCellUnavailableTimeFault": 0,
        "OnGoRadio001_1_TotalCellUnavailableTimeManualIntervention": random.randint(200, 400),
        "OnGoRadio001_2_TotalCellUnavailableTime": random.randint(200, 400),
        "OnGoRadio001_2_TotalCellUnavailableTimeFault": random.randint(200, 400),
        "OnGoRadio001_2_TotalCellUnavailableTimeManualIntervention": 0,
        "OnGoRadio001_1_DrbULThCapacitySum": 0,
        "OnGoRadio001_1_DrbULThCapacityAvg": 0,
        "OnGoRadio001_1_DrbMaxULThCapacity": 0,
        "OnGoRadio001_1_DrbDLThCapacityAvg": 0,
        "OnGoRadio001_1_DrbPdcpSduLossRateUlSum": 0,
        "OnGoRadio001_1_DrbDLThCapacitySum": 0,
        "OnGoRadio001_1_DrbPdcpSduAirLossRateDlSum": 0,
        "OnGoRadio001_2_DrbULThCapacitySum": 0,
        "OnGoRadio001_2_DrbULThCapacityAvg": 0,
        "OnGoRadio001_2_DrbMaxULThCapacity": 0,
        "OnGoRadio001_2_DrbDLThCapacityAvg": 0,
        "OnGoRadio001_2_DrbPdcpSduLossRateUlSum": 0,
        "OnGoRadio001_2_DrbDLThCapacitySum": 0,
        "OnGoRadio001_2_DrbPdcpSduAirLossRateDlSum": 0,
        "OnGoRadio001_1_PdcpSduDropRateDl": 0,
        "OnGoRadio001_1_PdcpTrafficDlKbps": 0,
        "OnGoRadio001_1_PdcpTrafficUlKbps": 0,
        "OnGoRadio001_1_RbDlIpLatency": 0,
        "OnGoRadio001_1_IpLateSamplesDl": 0,
        "OnGoRadio001_1_PdcpSduAirTotalDl": 0,
        "OnGoRadio001_1_PdcpSduAirLossDl": 0,
        "OnGoRadio001_1_PdcpSduAirLossRateDl": 0,
        "OnGoRadio001_2_PdcpSduDropRateDl": 0,
        "OnGoRadio001_2_PdcpTrafficDlKbps": 0,
        "OnGoRadio001_2_PdcpTrafficUlKbps": 0,
        "OnGoRadio001_2_RbDlIpLatency": 0,
        "OnGoRadio001_2_IpLateSamplesDl": 0,
        "OnGoRadio001_2_PdcpSduAirTotalDl": 0,
        "OnGoRadio001_2_PdcpSduAirLossDl": 0,
        "OnGoRadio001_2_PdcpSduAirLossRateDl": 0
    }

    return data1, data2, data3

# %%
data={
  "BETAZRPDCOR001_1_totalAttachedUser": 2,
  "BETAZRPDCOR001_1_totalRejectedUser": 0,
  "BETAZRPDCOR001_1_totalBearerActiveUser": 19802,
  "BETAZRPDCOR001_1_totalBearerRejectedUser": 0,
  "BETAZRPDCOR001_1_handoverFailureCount": 0,
  "BETAZRPDCOR001_1_peak_ul": "nan",
  "BETAZRPDCOR001_1_peak_dl": "nan",
  "BETAZRPDCOR001_1_total_dropped_packets": 0,
  "BETAZRPDCOR001_1_total_users": 0,
  "BETAZRPDCOR001_1_enodeb_connected_count": 1,
  "BETAZRPDCOR001_1_enodeb_shutdown_count": 2,
  "BETAZRPDCOR001_1_enodeb_connection_status": 33.33333333333333,
  "BETBELPDENB001_1_ConnEstabFailSum": "0",
  "BETBELPDENB001_1_ConnEstabSuccSum": "30",
  "BETBELPDENB001_2_ConnEstabFailSum": "0",
  "BETBELPDENB001_2_ConnEstabSuccSum": "29",
  "DFWIRV01ENB002_1_ConnEstabFailSum": "0",
  "DFWIRV01ENB002_1_ConnEstabSuccSum": "0",
  "DFWIRV01ENB002_2_ConnEstabFailSum": "0",
  "DFWIRV01ENB002_2_ConnEstabSuccSum": "0",
  "BETBELPDENB001_1_TotalCellUnavailableTimeFault": "0",
  "BETBELPDENB001_1_TotalCellUnavailableTimeManualIntervention": "0",
  "BETBELPDENB001_1_TotalCellUnavailableTime": "0",
  "BETBELPDENB001_2_TotalCellUnavailableTimeFault": "0",
  "BETBELPDENB001_2_TotalCellUnavailableTimeManualIntervention": "0",
  "BETBELPDENB001_2_TotalCellUnavailableTime": "0",
  "DFWIRV01ENB002_1_TotalCellUnavailableTimeFault": "0",
  "DFWIRV01ENB002_1_TotalCellUnavailableTimeManualIntervention": "0",
  "DFWIRV01ENB002_1_TotalCellUnavailableTime": "0",
  "DFWIRV01ENB002_2_TotalCellUnavailableTimeFault": "0",
  "DFWIRV01ENB002_2_TotalCellUnavailableTimeManualIntervention": "0",
  "DFWIRV01ENB002_2_TotalCellUnavailableTime": "0",
  "BETBELPDENB001_1_DrbULThCapacitySum": "5923969",
  "BETBELPDENB001_1_DrbPdcpSduAirLossRateDlSum": "0",
  "BETBELPDENB001_1_DrbMaxULThCapacity": "38400",
  "BETBELPDENB001_1_DrbPdcpSduLossRateUlSum": "0",
  "BETBELPDENB001_1_DrbDLThCapacitySum": "5137730",
  "BETBELPDENB001_1_DrbULThCapacityAvg": "24081.17",
  "BETBELPDENB001_1_DrbDLThCapacityAvg": "20227.28",
  "BETBELPDENB001_2_DrbULThCapacitySum": "1186198",
  "BETBELPDENB001_2_DrbPdcpSduAirLossRateDlSum": "0",
  "BETBELPDENB001_2_DrbMaxULThCapacity": "38400",
  "BETBELPDENB001_2_DrbPdcpSduLossRateUlSum": "0",
  "BETBELPDENB001_2_DrbDLThCapacitySum": "2859731",
  "BETBELPDENB001_2_DrbULThCapacityAvg": "21567.24",
  "BETBELPDENB001_2_DrbDLThCapacityAvg": "20573.6",
  "DFWIRV01ENB002_1_DrbULThCapacitySum": "0",
  "DFWIRV01ENB002_1_DrbPdcpSduAirLossRateDlSum": "0",
  "DFWIRV01ENB002_1_DrbMaxULThCapacity": "0",
  "DFWIRV01ENB002_1_DrbPdcpSduLossRateUlSum": "0",
  "DFWIRV01ENB002_1_DrbDLThCapacitySum": "0",
  "DFWIRV01ENB002_1_DrbULThCapacityAvg": "nan",
  "DFWIRV01ENB002_1_DrbDLThCapacityAvg": "nan",
  "DFWIRV01ENB002_2_DrbULThCapacitySum": "0",
  "DFWIRV01ENB002_2_DrbPdcpSduAirLossRateDlSum": "0",
  "DFWIRV01ENB002_2_DrbMaxULThCapacity": "0",
  "DFWIRV01ENB002_2_DrbPdcpSduLossRateUlSum": "0",
  "DFWIRV01ENB002_2_DrbDLThCapacitySum": "0",
  "DFWIRV01ENB002_2_DrbULThCapacityAvg": "nan",
  "DFWIRV01ENB002_2_DrbDLThCapacityAvg": "nan",
  "BETBELLBENB001_1_RbDlIpLatency": "0",
  "BETBELLBENB001_1_PdcpSduAirLossDl": "0",
  "BETBELLBENB001_1_PdcpSduDropRateDl": "0",
  "BETBELLBENB001_1_PdcpTrafficUlKbps": "0",
  "BETBELLBENB001_1_IpLateSamplesDl": "0",
  "BETBELLBENB001_1_PdcpSduAirTotalDl": "0",
  "BETBELLBENB001_1_PdcpSduAirLossRateDl": "0",
  "BETBELLBENB001_1_PdcpTrafficDlKbps": "0",
  "BETBELLBENB001_2_RbDlIpLatency": "0",
  "BETBELLBENB001_2_PdcpSduAirLossDl": "0",
  "BETBELLBENB001_2_PdcpSduDropRateDl": "0",
  "BETBELLBENB001_2_PdcpTrafficUlKbps": "0",
  "BETBELLBENB001_2_IpLateSamplesDl": "0",
  "BETBELLBENB001_2_PdcpSduAirTotalDl": "0",
  "BETBELLBENB001_2_PdcpSduAirLossRateDl": "0",
  "BETBELLBENB001_2_PdcpTrafficDlKbps": "0",
  "BETBELPDENB001_1_RbDlIpLatency": "0",
  "BETBELPDENB001_1_PdcpSduAirLossDl": "0",
  "BETBELPDENB001_1_PdcpSduDropRateDl": "0",
  "BETBELPDENB001_1_PdcpTrafficUlKbps": "0",
  "BETBELPDENB001_1_IpLateSamplesDl": "0",
  "BETBELPDENB001_1_PdcpSduAirTotalDl": "0",
  "BETBELPDENB001_1_PdcpSduAirLossRateDl": "0",
  "BETBELPDENB001_1_PdcpTrafficDlKbps": "0",
  "BETBELPDENB001_2_RbDlIpLatency": "0",
  "BETBELPDENB001_2_PdcpSduAirLossDl": "0",
  "BETBELPDENB001_2_PdcpSduDropRateDl": "0",
  "BETBELPDENB001_2_PdcpTrafficUlKbps": "0",
  "BETBELPDENB001_2_IpLateSamplesDl": "0",
  "BETBELPDENB001_2_PdcpSduAirTotalDl": "0",
  "BETBELPDENB001_2_PdcpSduAirLossRateDl": "0",
  "BETBELPDENB001_2_PdcpTrafficDlKbps": "0",
  "DFWIRV01ENB001_1_RbDlIpLatency": "0",
  "DFWIRV01ENB001_1_PdcpSduAirLossDl": "0",
  "DFWIRV01ENB001_1_PdcpSduDropRateDl": "0",
  "DFWIRV01ENB001_1_PdcpTrafficUlKbps": "0",
  "DFWIRV01ENB001_1_IpLateSamplesDl": "0",
  "DFWIRV01ENB001_1_PdcpSduAirTotalDl": "0",
  "DFWIRV01ENB001_1_PdcpSduAirLossRateDl": "0",
  "DFWIRV01ENB001_1_PdcpTrafficDlKbps": "0",
  "DFWIRV01ENB001_2_RbDlIpLatency": "0",
  "DFWIRV01ENB001_2_PdcpSduAirLossDl": "0",
  "DFWIRV01ENB001_2_PdcpSduDropRateDl": "0",
  "DFWIRV01ENB001_2_PdcpTrafficUlKbps": "0",
  "DFWIRV01ENB001_2_IpLateSamplesDl": "0",
  "DFWIRV01ENB001_2_PdcpSduAirTotalDl": "0",
  "DFWIRV01ENB001_2_PdcpSduAirLossRateDl": "0",
  "DFWIRV01ENB001_2_PdcpTrafficDlKbps": "0",
  "DFWIRV01ENB002_1_RbDlIpLatency": "0",
  "DFWIRV01ENB002_1_PdcpSduAirLossDl": "0",
  "DFWIRV01ENB002_1_PdcpSduDropRateDl": "0",
  "DFWIRV01ENB002_1_PdcpTrafficUlKbps": "0",
  "DFWIRV01ENB002_1_IpLateSamplesDl": "0",
  "DFWIRV01ENB002_1_PdcpSduAirTotalDl": "0",
  "DFWIRV01ENB002_1_PdcpSduAirLossRateDl": "0",
  "DFWIRV01ENB002_1_PdcpTrafficDlKbps": "0",
  "DFWIRV01ENB002_2_RbDlIpLatency": "0",
  "DFWIRV01ENB002_2_PdcpSduAirLossDl": "0",
  "DFWIRV01ENB002_2_PdcpSduDropRateDl": "0",
  "DFWIRV01ENB002_2_PdcpTrafficUlKbps": "0",
  "DFWIRV01ENB002_2_IpLateSamplesDl": "0",
  "DFWIRV01ENB002_2_PdcpSduAirTotalDl": "0",
  "DFWIRV01ENB002_2_PdcpSduAirLossRateDl": "0",
  "DFWIRV01ENB002_2_PdcpTrafficDlKbps": "0",
  "BETBELLBENB001_1_ConnEstabSuccSum": "8",
  "BETBELLBENB001_1_ConnEstabFailSum": "0",
  "BETBELLBENB001_2_ConnEstabSuccSum": "0",
  "BETBELLBENB001_2_ConnEstabFailSum": "0",
  "BETBELLBENB001_1_TotalCellUnavailableTime": "0",
  "BETBELLBENB001_1_TotalCellUnavailableTimeFault": "0",
  "BETBELLBENB001_1_TotalCellUnavailableTimeManualIntervention": "0",
  "BETBELLBENB001_2_TotalCellUnavailableTime": "0",
  "BETBELLBENB001_2_TotalCellUnavailableTimeFault": "0",
  "BETBELLBENB001_2_TotalCellUnavailableTimeManualIntervention": "0",
  "BETBELLBENB001_1_DrbDLThCapacityAvg": "12109.32",
  "BETBELLBENB001_1_DrbDLThCapacitySum": "496482",
  "BETBELLBENB001_1_DrbPdcpSduLossRateUlSum": "0",
  "BETBELLBENB001_1_DrbULThCapacitySum": "544340",
  "BETBELLBENB001_1_DrbMaxULThCapacity": "19274",
  "BETBELLBENB001_1_DrbPdcpSduAirLossRateDlSum": "0",
  "BETBELLBENB001_1_DrbULThCapacityAvg": "17559.35",
  "BETBELLBENB001_2_DrbDLThCapacityAvg": "nan",
  "BETBELLBENB001_2_DrbDLThCapacitySum": "0",
  "BETBELLBENB001_2_DrbPdcpSduLossRateUlSum": "0",
  "BETBELLBENB001_2_DrbULThCapacitySum": "0",
  "BETBELLBENB001_2_DrbMaxULThCapacity": "0",
  "BETBELLBENB001_2_DrbPdcpSduAirLossRateDlSum": "0",
  "BETBELLBENB001_2_DrbULThCapacityAvg": "nan",
  "DFWIRV01ENB001_1_latitude": 32.906672,
  "DFWIRV01ENB001_1_longitude": -97.036331,
  "DFWIRV01ENB002_1_latitude": 32.907385,
  "DFWIRV01ENB002_1_longitude": -97.038826,
  "DFWIRV01ENB001_1_ConnEstabSuccSum": "0",
  "DFWIRV01ENB001_1_ConnEstabFailSum": "0",
  "DFWIRV01ENB001_2_ConnEstabSuccSum": "0",
  "DFWIRV01ENB001_2_ConnEstabFailSum": "0",
  "DFWIRV01ENB001_1_TotalCellUnavailableTimeManualIntervention": "0",
  "DFWIRV01ENB001_1_TotalCellUnavailableTime": "0",
  "DFWIRV01ENB001_1_TotalCellUnavailableTimeFault": "0",
  "DFWIRV01ENB001_2_TotalCellUnavailableTimeManualIntervention": "0",
  "DFWIRV01ENB001_2_TotalCellUnavailableTime": "0",
  "DFWIRV01ENB001_2_TotalCellUnavailableTimeFault": "0",
  "DFWIRV01ENB001_1_DrbDLThCapacitySum": "0",
  "DFWIRV01ENB001_1_DrbDLThCapacityAvg": "nan",
  "DFWIRV01ENB001_1_DrbMaxULThCapacity": "0",
  "DFWIRV01ENB001_1_DrbULThCapacitySum": "0",
  "DFWIRV01ENB001_1_DrbPdcpSduLossRateUlSum": "0",
  "DFWIRV01ENB001_1_DrbULThCapacityAvg": "nan",
  "DFWIRV01ENB001_1_DrbPdcpSduAirLossRateDlSum": "0",
  "DFWIRV01ENB001_2_DrbDLThCapacitySum": "0",
  "DFWIRV01ENB001_2_DrbDLThCapacityAvg": "nan",
  "DFWIRV01ENB001_2_DrbMaxULThCapacity": "0",
  "DFWIRV01ENB001_2_DrbULThCapacitySum": "0",
  "DFWIRV01ENB001_2_DrbPdcpSduLossRateUlSum": "0",
  "DFWIRV01ENB001_2_DrbULThCapacityAvg": "nan",
  "DFWIRV01ENB001_2_DrbPdcpSduAirLossRateDlSum": "0",
  "DFWIRV01ENB001_2_latitude": 32.906672,
  "DFWIRV01ENB001_2_longitude": -97.036331,
  "DFWIRV01ENB002_2_latitude": 32.907385,
  "DFWIRV01ENB002_2_longitude": -97.038826,
  "BETBELPDENB001_1_latitude": 47.611904,
  "BETBELPDENB001_1_longitude": -122.196682,
  "BETBELLBENB001_1_latitude": 7.611902,
  "BETBELLBENB001_1_longitude": -122.196841,
  "OnGoRadio001_1_ConnEstabFailSum": "0",
  "OnGoRadio001_1_ConnEstabSuccSum": "0",
  "OnGoRadio001_2_ConnEstabFailSum": "0",
  "OnGoRadio001_2_ConnEstabSuccSum": "0",
  "OnGoRadio001_1_TotalCellUnavailableTime": "300",
  "OnGoRadio001_1_TotalCellUnavailableTimeFault": "0",
  "OnGoRadio001_1_TotalCellUnavailableTimeManualIntervention": "300",
  "OnGoRadio001_2_TotalCellUnavailableTime": "300",
  "OnGoRadio001_2_TotalCellUnavailableTimeFault": "300",
  "OnGoRadio001_2_TotalCellUnavailableTimeManualIntervention": "0",
  "OnGoRadio001_1_DrbULThCapacitySum": "0",
  "OnGoRadio001_1_DrbULThCapacityAvg": "nan",
  "OnGoRadio001_1_DrbMaxULThCapacity": "0",
  "OnGoRadio001_1_DrbDLThCapacityAvg": "nan",
  "OnGoRadio001_1_DrbPdcpSduLossRateUlSum": "0",
  "OnGoRadio001_1_DrbDLThCapacitySum": "0",
  "OnGoRadio001_1_DrbPdcpSduAirLossRateDlSum": "0",
  "OnGoRadio001_2_DrbULThCapacitySum": "0",
  "OnGoRadio001_2_DrbULThCapacityAvg": "nan",
  "OnGoRadio001_2_DrbMaxULThCapacity": "0",
  "OnGoRadio001_2_DrbDLThCapacityAvg": "nan",
  "OnGoRadio001_2_DrbPdcpSduLossRateUlSum": "0",
  "OnGoRadio001_2_DrbDLThCapacitySum": "0",
  "OnGoRadio001_2_DrbPdcpSduAirLossRateDlSum": "0",
  "OnGoRadio001_1_PdcpSduDropRateDl": "0",
  "OnGoRadio001_1_PdcpTrafficDlKbps": "0",
  "OnGoRadio001_1_PdcpTrafficUlKbps": "0",
  "OnGoRadio001_1_RbDlIpLatency": "0",
  "OnGoRadio001_1_IpLateSamplesDl": "0",
  "OnGoRadio001_1_PdcpSduAirTotalDl": "0",
  "OnGoRadio001_1_PdcpSduAirLossDl": "0",
  "OnGoRadio001_1_PdcpSduAirLossRateDl": "0",
  "OnGoRadio001_2_PdcpSduDropRateDl": "0",
  "OnGoRadio001_2_PdcpTrafficDlKbps": "0",
  "OnGoRadio001_2_PdcpTrafficUlKbps": "0",
  "OnGoRadio001_2_RbDlIpLatency": "0",
  "OnGoRadio001_2_IpLateSamplesDl": "0",
  "OnGoRadio001_2_PdcpSduAirTotalDl": "0",
  "OnGoRadio001_2_PdcpSduAirLossDl": "0",
  "OnGoRadio001_2_PdcpSduAirLossRateDl": "0"
}

# %%
import time
import json
import random

i=5
while i>0:
    
    data1,data2,data3 = random_data()
    # Reading the json as a dict
    data={}
    data.update(data1)
    data.update(data2)
    data.update(data3)
    
    i-=1
    # Directly from dictionary
    with open('gyan-report.json', 'w') as outfile:
        json.dump(data, outfile)
    time.sleep(1)
    print("Complete")
# Out:
# Complete
# Complete
# Complete
# Complete
# Complete

# %% [markdown]
# ## Data Exploation

# %%
import numpy as np
for key,value in data.items():
    if value =="nan":
        data[key]=0
    
    data[key]= np.round(float(data[key]),2)

# %%
temp_data={}
for key,value in data.items():
    BS_Name= key.split("_")[0]
    Cell_Number = key.split("_")[1]
    
    temp_key= BS_Name+"_"+Cell_Number
    
    temp_data[BS_Name]= 0
    #temp_data[temp_key]= 0
temp_data
# Out:
# {'BETAZRPDCOR001': 0,
#  'BETBELPDENB001': 0,
#  'DFWIRV01ENB002': 0,
#  'BETBELLBENB001': 0,
#  'DFWIRV01ENB001': 0,
#  'OnGoRadio001': 0}

# %%
temp_data
# Out:
# {'BETAZRPDCOR001_1': 0,
#  'BETBELPDENB001_1': 0,
#  'BETBELPDENB001_2': 0,
#  'DFWIRV01ENB002_1': 0,
#  'DFWIRV01ENB002_2': 0,
#  'BETBELLBENB001_1': 0,
#  'BETBELLBENB001_2': 0,
#  'DFWIRV01ENB001_1': 0,
#  'DFWIRV01ENB001_2': 0,
#  'OnGoRadio001_1': 0,
#  'OnGoRadio001_2': 0}

# %%
temp_data2={}
str_len= len("DFWIRV01ENB001_2_")
for key,value in data.items():
    temp_key2= key[str_len:]
    
    temp_data2[temp_key2]= value

# %%
temp_data2
# Out:
# {'totalAttachedUser': 2.0,
#  'totalRejectedUser': 0.0,
#  'totalBearerActiveUser': 19802.0,
#  'totalBearerRejectedUser': 0.0,
#  'handoverFailureCount': 0.0,
#  'peak_ul': 0.0,
#  'peak_dl': 0.0,
#  'total_dropped_packets': 0.0,
#  'total_users': 0.0,
#  'enodeb_connected_count': 1.0,
#  'enodeb_shutdown_count': 2.0,
#  'enodeb_connection_status': 33.33,
#  'ConnEstabFailSum': 0.0,
#  'ConnEstabSuccSum': 0.0,
#  'TotalCellUnavailableTimeFault': 0.0,
#  'TotalCellUnavailableTimeManualIntervention': 0.0,
#  'TotalCellUnavailableTime': 0.0,
#  'DrbULThCapacitySum': 0.0,
#  'DrbPdcpSduAirLossRateDlSum': 0.0,
#  'DrbMaxULThCapacity': 0.0,
#  'DrbPdcpSduLossRateUlSum': 0.0,
#  'DrbDLThCapacitySum': 0.0,
#  'DrbULThCapacityAvg': 0.0,
#  'DrbDLThCapacityAvg': 0.0,
#  'RbDlIpLatency': 0.0,
#  'PdcpSduAirLossDl': 0.0,
#  'PdcpSduDropRateDl': 0.0,
#  'PdcpTrafficUlKbps': 0.0,
#  'IpLateSamplesDl': 0.0,
#  'PdcpSduAirTotalDl': 0.0,
#  'PdcpSduAirLossRateDl': 0.0,
#  'PdcpTrafficDlKbps': 0.0,
# ...

# %% [markdown]
# ## Simple Data Generation for Ran

# %%
# BETAZRPDCOR001_1

data1_1 = {
    "BETAZRPDCOR001_1_totalAttachedUser": random.randint(1,10),
    "BETAZRPDCOR001_1_totalRejectedUser": 0,
    "BETAZRPDCOR001_1_totalBearerActiveUser": random.randint(3000,10000),
    "BETAZRPDCOR001_1_totalBearerRejectedUser": 0,
    "BETAZRPDCOR001_1_handoverFailureCount": 0,
    "BETAZRPDCOR001_1_peak_ul": random.randint(10,80),
    "BETAZRPDCOR001_1_peak_dl": random.randint(100,190),
    "BETAZRPDCOR001_1_total_dropped_packets": 0,
    "BETAZRPDCOR001_1_total_users": random.randint(1,25),
    "BETAZRPDCOR001_1_enodeb_connected_count": random.randint(1,4),
    "BETAZRPDCOR001_1_enodeb_shutdown_count": random.randint(1,4),
    "BETAZRPDCOR001_1_enodeb_connection_status": 100}

# %%
#BETBELPDENB001_1
data2_1 = {
    "BETBELPDENB001_1_totalAttachedUser": random.randint(1,10),
    "BETBELPDENB001_1_totalRejectedUser": 0,
    "BETBELPDENB001_1_totalBearerActiveUser": random.randint(3000,10000),
    "BETBELPDENB001_1_totalBearerRejectedUser": 0,
    "BETBELPDENB001_1_handoverFailureCount": 0,
    "BETBELPDENB001_1_peak_ul": random.randint(10,80),
    "BETBELPDENB001_1_peak_dl": random.randint(100,190),
    "BETBELPDENB001_1_total_dropped_packets": 0,
    "BETBELPDENB001_1_total_users": random.randint(1,25),
    "BETBELPDENB001_1_enodeb_connected_count": random.randint(1,4),
    "BETBELPDENB001_1_enodeb_shutdown_count": random.randint(1,4),
    "BETBELPDENB001_1_enodeb_connection_status": 100}

#BETBELPDENB001_2
data2_2 = {
    "BETBELPDENB001_2_totalAttachedUser": random.randint(1,10),
    "BETBELPDENB001_2_totalRejectedUser": 0,
    "BETBELPDENB001_2_totalBearerActiveUser": random.randint(3000,10000),
    "BETBELPDENB001_2_totalBearerRejectedUser": 0,
    "BETBELPDENB001_2_handoverFailureCount": 0,
    "BETBELPDENB001_2_peak_ul": random.randint(10,80),
    "BETBELPDENB001_2_peak_dl": random.randint(100,190),
    "BETBELPDENB001_2_total_dropped_packets": 0,
    "BETBELPDENB001_2_total_users": random.randint(1,25),
    "BETBELPDENB001_2_enodeb_connected_count": random.randint(1,4),
    "BETBELPDENB001_2_enodeb_shutdown_count": random.randint(1,4),
    "BETBELPDENB001_2_enodeb_connection_status": 100}

# %%
#DFWIRV01ENB002_1
data3_1 = {
    "DFWIRV01ENB002_1_totalAttachedUser": random.randint(1,10),
    "DFWIRV01ENB002_1_totalRejectedUser": 0,
    "DFWIRV01ENB002_1_totalBearerActiveUser": random.randint(3000,10000),
    "DFWIRV01ENB002_1_totalBearerRejectedUser": 0,
    "DFWIRV01ENB002_1_handoverFailureCount": 0,
    "DFWIRV01ENB002_1_peak_ul": random.randint(10,80),
    "DFWIRV01ENB002_1_peak_dl": random.randint(100,190),
    "DFWIRV01ENB002_1_total_dropped_packets": 0,
    "DFWIRV01ENB002_1_total_users": random.randint(1,25),
    "DFWIRV01ENB002_1_enodeb_connected_count": random.randint(1,4),
    "DFWIRV01ENB002_1_enodeb_shutdown_count": random.randint(1,4),
    "DFWIRV01ENB002_1_enodeb_connection_status": 100}

#DFWIRV01ENB002_2
data3_2 = {
    "DFWIRV01ENB002_2_totalAttachedUser": random.randint(1,10),
    "DFWIRV01ENB002_2_totalRejectedUser": 0,
    "DFWIRV01ENB002_2_totalBearerActiveUser": random.randint(3000,10000),
    "DFWIRV01ENB002_2_totalBearerRejectedUser": 0,
    "DFWIRV01ENB002_2_handoverFailureCount": 0,
    "DFWIRV01ENB002_2_peak_ul": random.randint(10,80),
    "DFWIRV01ENB002_2_peak_dl": random.randint(100,190),
    "DFWIRV01ENB002_2_total_dropped_packets": 0,
    "DFWIRV01ENB002_2_total_users": random.randint(1,25),
    "DFWIRV01ENB002_2_enodeb_connected_count": random.randint(1,4),
    "DFWIRV01ENB002_2_enodeb_shutdown_count": random.randint(1,4),
    "DFWIRV01ENB002_2_enodeb_connection_status": 100}

# %%
#BETBELLBENB001_1

data4_1 = {
    "BETBELLBENB001_1_totalAttachedUser": random.randint(1,10),
    "BETBELLBENB001_1_totalRejectedUser": 0,
    "BETBELLBENB001_1_totalBearerActiveUser": random.randint(3000,10000),
    "BETBELLBENB001_1_totalBearerRejectedUser": 0,
    "BETBELLBENB001_1_handoverFailureCount": 0,
    "BETBELLBENB001_1_peak_ul": random.randint(10,80),
    "BETBELLBENB001_1_peak_dl": random.randint(100,190),
    "BETBELLBENB001_1_total_dropped_packets": 0,
    "BETBELLBENB001_1_total_users": random.randint(1,25),
    "BETBELLBENB001_1_enodeb_connected_count": random.randint(1,4),
    "BETBELLBENB001_1_enodeb_shutdown_count": random.randint(1,4),
    "BETBELLBENB001_1_enodeb_connection_status": 100}

#BETBELLBENB001_2
data4_2 = {
    "BETBELLBENB001_2_totalAttachedUser": random.randint(1,10),
    "BETBELLBENB001_2_totalRejectedUser": 0,
    "BETBELLBENB001_2_totalBearerActiveUser": random.randint(3000,10000),
    "BETBELLBENB001_2_totalBearerRejectedUser": 0,
    "BETBELLBENB001_2_handoverFailureCount": 0,
    "BETBELLBENB001_2_peak_ul": random.randint(10,80),
    "BETBELLBENB001_2_peak_dl": random.randint(100,190),
    "BETBELLBENB001_2_total_dropped_packets": 0,
    "BETBELLBENB001_2_total_users": random.randint(1,25),
    "BETBELLBENB001_2_enodeb_connected_count": random.randint(1,4),
    "BETBELLBENB001_2_enodeb_shutdown_count": random.randint(1,4),
    "BETBELLBENB001_2_enodeb_connection_status": 100}

# %%
#DFWIRV01ENB001_1
data5_1 = {
    "DFWIRV01ENB001_1_totalAttachedUser": random.randint(1,10),
    "DFWIRV01ENB001_1_totalRejectedUser": 0,
    "DFWIRV01ENB001_1_totalBearerActiveUser": random.randint(3000,10000),
    "DFWIRV01ENB001_1_totalBearerRejectedUser": 0,
    "DFWIRV01ENB001_1_handoverFailureCount": 0,
    "DFWIRV01ENB001_1_peak_ul": random.randint(10,80),
    "DFWIRV01ENB001_1_peak_dl": random.randint(100,190),
    "DFWIRV01ENB001_1_total_dropped_packets": 0,
    "DFWIRV01ENB001_1_total_users": random.randint(1,25),
    "DFWIRV01ENB001_1_enodeb_connected_count": random.randint(1,4),
    "DFWIRV01ENB001_1_enodeb_shutdown_count": random.randint(1,4),
    "DFWIRV01ENB001_1_enodeb_connection_status": 100}

#DFWIRV01ENB001_2
data5_2 = {
    "DFWIRV01ENB001_2_totalAttachedUser": random.randint(1,10),
    "DFWIRV01ENB001_2_totalRejectedUser": 0,
    "DFWIRV01ENB001_2_totalBearerActiveUser": random.randint(3000,10000),
    "DFWIRV01ENB001_2_totalBearerRejectedUser": 0,
    "DFWIRV01ENB001_2_handoverFailureCount": 0,
    "DFWIRV01ENB001_2_peak_ul": random.randint(10,80),
    "DFWIRV01ENB001_2_peak_dl": random.randint(100,190),
    "DFWIRV01ENB001_2_total_dropped_packets": 0,
    "DFWIRV01ENB001_2_total_users": random.randint(1,25),
    "DFWIRV01ENB001_2_enodeb_connected_count": random.randint(1,4),
    "DFWIRV01ENB001_2_enodeb_shutdown_count": random.randint(1,4),
    "DFWIRV01ENB001_2_enodeb_connection_status": 100}

# %%
#OnGoRadio001_1
data6_1 = {
    "OnGoRadio001_1_totalAttachedUser": random.randint(1,10),
    "OnGoRadio001_1_totalRejectedUser": 0,
    "OnGoRadio001_1_totalBearerActiveUser": random.randint(3000,10000),
    "OnGoRadio001_1_totalBearerRejectedUser": 0,
    "OnGoRadio001_1_handoverFailureCount": 0,
    "OnGoRadio001_1_peak_ul": random.randint(10,80),
    "OnGoRadio001_1_peak_dl": random.randint(100,190),
    "OnGoRadio001_1_total_dropped_packets": 0,
    "OnGoRadio001_1_total_users": random.randint(1,25),
    "OnGoRadio001_1_enodeb_connected_count": random.randint(1,4),
    "OnGoRadio001_1_enodeb_shutdown_count": random.randint(1,4),
    "OnGoRadio001_1_enodeb_connection_status": 100}

#OnGoRadio001_2
data6_2 = {
    "OnGoRadio001_2_totalAttachedUser": random.randint(1,10),
    "OnGoRadio001_2_totalRejectedUser": 0,
    "OnGoRadio001_2_totalBearerActiveUser": random.randint(3000,10000),
    "OnGoRadio001_2_totalBearerRejectedUser": 0,
    "OnGoRadio001_2_handoverFailureCount": 0,
    "OnGoRadio001_2_peak_ul": random.randint(10,80),
    "OnGoRadio001_2_peak_dl": random.randint(100,190),
    "OnGoRadio001_2_total_dropped_packets": 0,
    "OnGoRadio001_2_total_users": random.randint(1,25),
    "OnGoRadio001_2_enodeb_connected_count": random.randint(1,4),
    "OnGoRadio001_2_enodeb_shutdown_count": random.randint(1,4),
    "OnGoRadio001_2_enodeb_connection_status": 100}

# %%
final= {}

final.update(data1_1)
final.update(data2_1)
final.update(data2_2)
final.update(data3_1)
final.update(data3_2)
final.update(data4_1)
final.update(data4_2)
final.update(data5_1)
final.update(data5_2)
final.update(data6_1)
final.update(data6_2)

# %%
len(final)
# Out:
# 132

# %%
final
# Out:
# {'BETAZRPDCOR001_1_totalAttachedUser': 6,
#  'BETAZRPDCOR001_1_totalRejectedUser': 0,
#  'BETAZRPDCOR001_1_totalBearerActiveUser': 7091,
#  'BETAZRPDCOR001_1_totalBearerRejectedUser': 0,
#  'BETAZRPDCOR001_1_handoverFailureCount': 0,
#  'BETAZRPDCOR001_1_peak_ul': 64,
#  'BETAZRPDCOR001_1_peak_dl': 155,
#  'BETAZRPDCOR001_1_total_dropped_packets': 0,
#  'BETAZRPDCOR001_1_total_users': 6,
#  'BETAZRPDCOR001_1_enodeb_connected_count': 2,
#  'BETAZRPDCOR001_1_enodeb_shutdown_count': 4,
#  'BETAZRPDCOR001_1_enodeb_connection_status': 100,
#  'BETBELPDENB001_1_totalAttachedUser': 7,
#  'BETBELPDENB001_1_totalRejectedUser': 0,
#  'BETBELPDENB001_1_totalBearerActiveUser': 3529,
#  'BETBELPDENB001_1_totalBearerRejectedUser': 0,
#  'BETBELPDENB001_1_handoverFailureCount': 0,
#  'BETBELPDENB001_1_peak_ul': 71,
#  'BETBELPDENB001_1_peak_dl': 145,
#  'BETBELPDENB001_1_total_dropped_packets': 0,
#  'BETBELPDENB001_1_total_users': 13,
#  'BETBELPDENB001_1_enodeb_connected_count': 4,
# ...

# %%
# f = open(r'gyan-report.json','r')

# %% [markdown]
# ## New
# 1. A randomized set of data with approximate range
# 2. dump data

# %%
import pandas as pd

# %%
#f = open(r'.json','w')
#sys.stdout = f
#print(json_string)
#sys.stdout.close()
